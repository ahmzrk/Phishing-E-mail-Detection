# %%
import import_ipynb
from preprocessing import load_data,clean_data, preprocessing,vectorize, split_data
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam

# %%
df = load_data("C:\Lib\Phishing_Email.csv")
df = clean_data(df)
df['Email Text'] = df['Email Text'].apply(preprocessing)
tf,X,y = vectorize(df)
X_train, X_test, y_train, y_test = split_data(X, y)
# Out:
# <string>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
all_mails = " ".join(df['Email Text'])

word_cloud = WordCloud(width=800,height=400,background_color='white',max_words=10000).generate(all_mails)
plt.figure(figsize=(10,6))
plt.imshow(word_cloud,interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 from wordcloud import WordCloud
#       3 all_mails = " ".join(df['Email Text'])
#       5 word_cloud = WordCloud(width=800,height=400,background_color='white',max_words=10000).generate(all_mails)
#
# ModuleNotFoundError: No module named 'wordcloud'

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2

model=Sequential()
model.add(Dense(32,activation='relu',input_shape=(10000,)))
model.add(Dropout(0.4))
model.add(Dense(16, activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dropout(0.2))
model.add(Dense(16, activation='relu'))
model.add(Dense(1,activation='sigmoid'))
model.summary()


optimizer = Adam(learning_rate=0.0005)
model.compile(
    optimizer=optimizer,
    loss='binary_crossentropy',
    metrics=['accuracy']
)


history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=128,
    validation_split=0.1,
    verbose=1
)
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_28 (Dense)                │ (None, 32)             │       320,032 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_29 (Dense)                │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_30 (Dense)                │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_31 (Dense)                │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 320,849 (1.22 MB)
#  Trainable params: 320,849 (1.22 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.6109 - loss: 0.8625 - val_accuracy: 0.8256 - val_loss: 0.6552
# Epoch 2/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8395 - loss: 0.5869 - val_accuracy: 0.9524 - val_loss: 0.3354
# Epoch 3/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9566 - loss: 0.3177 - val_accuracy: 0.9591 - val_loss: 0.2102
# Epoch 4/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9677 - loss: 0.2054 - val_accuracy: 0.9604 - val_loss: 0.1646
# Epoch 5/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9741 - loss: 0.1550 - val_accuracy: 0.9604 - val_loss: 0.1381
# Epoch 6/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9779 - loss: 0.1207 - val_accuracy: 0.9618 - val_loss: 0.1200
# Epoch 7/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9809 - loss: 0.0963 - val_accuracy: 0.9624 - val_loss: 0.1076
# Epoch 8/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9808 - loss: 0.0831 - val_accuracy: 0.9631 - val_loss: 0.1001
# Epoch 9/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9831 - loss: 0.0702 - val_accuracy: 0.9645 - val_loss: 0.0950
# Epoch 10/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9847 - loss: 0.0608 - val_accuracy: 0.9658 - val_loss: 0.0926
# Epoch 11/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9862 - loss: 0.0554 - val_accuracy: 0.9645 - val_loss: 0.0897
# Epoch 12/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9849 - loss: 0.0529 - val_accuracy: 0.9651 - val_loss: 0.0893
# Epoch 13/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9864 - loss: 0.0492 - val_accuracy: 0.9638 - val_loss: 0.0885
# Epoch 14/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9859 - loss: 0.0478 - val_accuracy: 0.9638 - val_loss: 0.0863
# Epoch 15/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9883 - loss: 0.0415 - val_accuracy: 0.9631 - val_loss: 0.0865
# Epoch 16/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9859 - loss: 0.0424 - val_accuracy: 0.9645 - val_loss: 0.0909
# Epoch 17/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9857 - loss: 0.0409 - val_accuracy: 0.9631 - val_loss: 0.0862
# Epoch 18/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9869 - loss: 0.0405 - val_accuracy: 0.9638 - val_loss: 0.0906
# Epoch 19/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9885 - loss: 0.0368 - val_accuracy: 0.9638 - val_loss: 0.0850
# Epoch 20/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9859 - loss: 0.0377 - val_accuracy: 0.9638 - val_loss: 0.0851
# Epoch 21/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9860 - loss: 0.0378 - val_accuracy: 0.9631 - val_loss: 0.0882
# Epoch 22/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9858 - loss: 0.0363 - val_accuracy: 0.9624 - val_loss: 0.0891
# Epoch 23/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9879 - loss: 0.0330 - val_accuracy: 0.9624 - val_loss: 0.0885
# Epoch 24/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9887 - loss: 0.0335 - val_accuracy: 0.9624 - val_loss: 0.0844
# Epoch 25/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9838 - loss: 0.0349 - val_accuracy: 0.9645 - val_loss: 0.0866
# Epoch 26/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9878 - loss: 0.0303 - val_accuracy: 0.9638 - val_loss: 0.0871
# Epoch 27/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9875 - loss: 0.0324 - val_accuracy: 0.9631 - val_loss: 0.0884
# Epoch 28/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9888 - loss: 0.0298 - val_accuracy: 0.9631 - val_loss: 0.0879
# Epoch 29/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9889 - loss: 0.0282 - val_accuracy: 0.9624 - val_loss: 0.0930
# Epoch 30/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9881 - loss: 0.0290 - val_accuracy: 0.9631 - val_loss: 0.0888
# Epoch 31/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9906 - loss: 0.0275 - val_accuracy: 0.9631 - val_loss: 0.0888
# Epoch 32/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9873 - loss: 0.0305 - val_accuracy: 0.9631 - val_loss: 0.0886
# Epoch 33/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9891 - loss: 0.0280 - val_accuracy: 0.9631 - val_loss: 0.0895
# Epoch 34/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9866 - loss: 0.0290 - val_accuracy: 0.9631 - val_loss: 0.0901
# Epoch 35/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9868 - loss: 0.0304 - val_accuracy: 0.9624 - val_loss: 0.0971
# Epoch 36/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9884 - loss: 0.0291 - val_accuracy: 0.9631 - val_loss: 0.0906
# Epoch 37/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9875 - loss: 0.0275 - val_accuracy: 0.9624 - val_loss: 0.0963
# Epoch 38/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9890 - loss: 0.0283 - val_accuracy: 0.9624 - val_loss: 0.0955
# Epoch 39/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9877 - loss: 0.0286 - val_accuracy: 0.9618 - val_loss: 0.0920
# Epoch 40/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9889 - loss: 0.0260 - val_accuracy: 0.9618 - val_loss: 0.0924
# Epoch 41/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9885 - loss: 0.0266 - val_accuracy: 0.9624 - val_loss: 0.0925
# Epoch 42/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9892 - loss: 0.0263 - val_accuracy: 0.9624 - val_loss: 0.0927
# Epoch 43/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9895 - loss: 0.0247 - val_accuracy: 0.9638 - val_loss: 0.0924
# Epoch 44/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9865 - loss: 0.0282 - val_accuracy: 0.9624 - val_loss: 0.0941
# Epoch 45/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9906 - loss: 0.0236 - val_accuracy: 0.9624 - val_loss: 0.0943
# Epoch 46/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9858 - loss: 0.0270 - val_accuracy: 0.9624 - val_loss: 0.0945
# Epoch 47/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9898 - loss: 0.0233 - val_accuracy: 0.9631 - val_loss: 0.0939
# Epoch 48/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9893 - loss: 0.0237 - val_accuracy: 0.9624 - val_loss: 0.0943
# Epoch 49/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9895 - loss: 0.0234 - val_accuracy: 0.9618 - val_loss: 0.0923
# Epoch 50/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9880 - loss: 0.0248 - val_accuracy: 0.9624 - val_loss: 0.0955

# %%
plt.plot(history.history['loss'], label='Eğitim Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.xlabel('Epochs')
plt.ylabel('bce')
plt.legend()
plt.show()

plt.plot(history.history['accuracy'], label='Eğitim Accuracy')
plt.plot(history.history['val_accuracy'], label='Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('acc')
plt.legend()
plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9715 - loss: 0.0864
# [0.09011167287826538, 0.9718272089958191]

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5).astype(int)  

cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Not Phishing', 'Phishing'], yticklabels=['Not Phishing', 'Phishing'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

print(classification_report(y_test, y_pred, target_names=['Not Phishing', 'Phishing']))
# Out:
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#               precision    recall  f1-score   support
#
# Not Phishing       0.95      0.98      0.97      1518
#     Phishing       0.98      0.97      0.98      2209
#
#     accuracy                           0.97      3727
#    macro avg       0.97      0.97      0.97      3727
# weighted avg       0.97      0.97      0.97      3727
